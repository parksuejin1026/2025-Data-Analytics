# %% [markdown]
# ### Lecture 21. 서울 지하철 승객 시간별 데이터 시각화

# %%
import csv

# %%
def addsome(value):
    return value + 10

lst = [10, 23, 4, 7]
result = map(addsome, lst) # 매핑 함수
list(result)
# Out:
# [20, 33, 14, 17]

# %%
def myreplace(s):
    return s.replace(',', '')

lst = ['34,000', '1,999', '2,786', '1,000,000']

result = map(int, map(myreplace, lst))
list(result)
# Out:
# [34000, 1999, 2786, 1000000]

# %%
int('101', 2)
# Out:
# 5

# %%
list(map(int, [3, 5, 11]))
# Out:
# [3, 5, 11]

# %%
list(map(int, ['3','5', 11]))
# Out:
# [3, 5, 11]

# %%
list(map(int, ['10','17','1f'], [2,8,16]))
# Out:
# [2, 15, 31]

# %%
(lambda x, y : x + y) (30, 4)
# Out:
# 34

# %%
lst = ['34,000', '1,999', '2,786', '1,000,000']
result = map(int, map(lambda s : s.replace(',', ''), lst))
list(result)
# Out:
# [34000, 1999, 2786, 1000000]

# %%
import csv 
f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)
next(data)  
result = []

for row in data:
    for i in range(4,52):
        row[i] = row[i].replace(',', '')
    
    row[4:] = map(int, row[4:])
    result.append(row[10]) # 오전 7시 승차 데이터

f.close()

print(len(result))
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 11
#       8     for i in range(4,52):
#       9         row[i] = row[i].replace(',', '')
# ---> 11     row[4:] = map(int, row[4:])
#      12     result.append(row[10]) # 오전 7시 승차 데이터
#      14 f.close()
#
# ValueError: invalid literal for int() with base 10: '승차'
